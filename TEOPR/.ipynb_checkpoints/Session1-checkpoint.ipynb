# %% [markdown]
# # Session 1 - Your "first" DataScience problem

# %%
# some imports

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.rc('font', size=12) 
plt.rc('figure', figsize = (12, 5))

# Settings for the visualizations
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})

import pandas as pd
pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 50)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# create output folder
if not os.path.exists('output'):
    os.makedirs('output')
if not os.path.exists('output/session1'):
    os.makedirs('output/session1')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
train_set = pd.read_csv('dataset/housing-snapshot/train_set.csv',index_col=0) 
test_set = pd.read_csv('dataset/housing-snapshot/test_set.csv',index_col=0)

# %% [markdown]
# ## The problem
# The machine learning is to predict the house price, but before that it is imporntat to study the dataset and its features

# %%
# print the dataset size
print("There is", train_set.shape[0], "samples")
print("Each sample has", train_set.shape[1], "features")
# Out:
# There is 5432 samples
# Each sample has 21 features

# %%
# print the top elements from the dataset
train_set.head()
# Out:
#                   Suburb           Address  Rooms Type      Price Method  \
# index
# 0             Aberfeldie    241 Buckley St      4    h  1380000.0     VB
# 1              Northcote     67 Charles St      2    h  1100000.0     SP
# 2           Balwyn North        42 Maud St      3    h  1480000.0     PI
# 3              Brunswick       13 Percy St      3    h  1055000.0      S
# 4      Templestowe Lower  253 Thompsons Rd      4    h  1000000.0     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# index
# 0             Nelson  12/08/2017       7.5    3040.0       4.0       2.0  2.0
# 1             Jellis  20/05/2017       5.5    3070.0       2.0       1.0  1.0
# 2             Jellis  15/10/2016       9.2    3104.0       3.0       1.0  4.0
# 3             Nelson   7/05/2016       5.2    3056.0       3.0       1.0  1.0
# 4      hockingstuart  13/08/2016      13.8    3107.0       4.0       3.0  2.0
#
#        Landsize  BuildingArea  YearBuilt    CouncilArea  Lattitude  \
# index
# 0         766.0           NaN        NaN  Moonee Valley  -37.75595
# 1         189.0           NaN        NaN        Darebin  -37.77670
# 2         605.0         116.0     1950.0     Boroondara  -37.79510
# 3         324.0           NaN     1930.0       Moreland  -37.76530
# 4         728.0         164.0     1970.0     Manningham  -37.76800
#
#        Longtitude             Regionname  Propertycount
# index
# 0       144.90551   Western Metropolitan         1543.0
# 1       144.99240  Northern Metropolitan        11364.0
# 2       145.06960  Southern Metropolitan         7809.0
# 3       144.95860  Northern Metropolitan        11918.0
# 4       145.10270   Eastern Metropolitan         5420.0

# %%
# As it can be seen the database contains several features, some of them numerical and some of them are categorical.
# It is important to check each of the to understand it.

# %%
# we can see the type of each features as follows
train_set.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
# print those categorical features
train_set.select_dtypes(include=['object']).head()
# Out:
#                   Suburb           Address Type Method        SellerG  \
# index
# 0             Aberfeldie    241 Buckley St    h     VB         Nelson
# 1              Northcote     67 Charles St    h     SP         Jellis
# 2           Balwyn North        42 Maud St    h     PI         Jellis
# 3              Brunswick       13 Percy St    h      S         Nelson
# 4      Templestowe Lower  253 Thompsons Rd    h     VB  hockingstuart
#
#              Date    CouncilArea             Regionname
# index
# 0      12/08/2017  Moonee Valley   Western Metropolitan
# 1      20/05/2017        Darebin  Northern Metropolitan
# 2      15/10/2016     Boroondara  Southern Metropolitan
# 3       7/05/2016       Moreland  Northern Metropolitan
# 4      13/08/2016     Manningham   Eastern Metropolitan

# %%
# We can check how many different type there is in the dataset using the folliwing line
train_set["Type"].value_counts()
# Out:
# h    3765
# u    1191
# t     476
# Name: Type, dtype: int64

# %%
sns.countplot(y="Type", data=train_set, color="c")

# %% [markdown]
# It would be interesting to visualize all features (numerical and catergorical) in order to undertand them.
#
# Check out this blog for plotting distribution: https://seaborn.pydata.org/tutorial/distributions.html
# + Seaborn version of this blog can be different from the one intalled in your machine (version 0.11 has been just realeased)
#
# Check out this blog for plotting categorical data: https://seaborn.pydata.org/tutorial/categorical.html

# %%
sns.distplot(train_set["Price"])
plt.show()

# %% [markdown]
# ## BASELINE MODEL
# ### https://www.kaggle.com/c/mlub-housing-house-prediction/notebooks
#
# This is a simple model that uses the K-nearest Neighbors Regressor
#
# This model only uses 4 feaures: 'Rooms','Landsize', 'BuildingArea', 'YearBuilt'

# %%
## the features

features = ['Rooms','Landsize', 'BuildingArea', 'YearBuilt']
## DEFINE YOUR FEATURES
X = train_set[features].fillna(0)
y = train_set[['Price']]

## the model
# KNeighborsRegressor
from sklearn import neighbors
n_neighbors = 3 # you can modify this paramenter (ONLY THIS ONE!!!)
model = neighbors.KNeighborsRegressor(n_neighbors)

## fit the model
model.fit(X, y)

## predict training set
y_pred = model.predict(X)

## Evaluate the model and plot it
from sklearn.metrics import mean_squared_error, r2_score
print("----- EVALUATION ON TRAIN SET ------")
print("RMSE",np.sqrt(mean_squared_error(y, y_pred)))
print("R^2: ",r2_score(y, y_pred))


plt.scatter(y, y_pred)
plt.xlabel('Price')
plt.ylabel('Predicted price');
plt.show()

## predict the test set and generate the submission file
X_test = test_set[features].fillna(0)
y_pred = model.predict(X_test)

df_output = pd.DataFrame(y_pred)
df_output = df_output.reset_index()
df_output.columns = ['index','Price']

df_output.to_csv('output/session1/baseline.csv',index=False)
# Out:
# ----- EVALUATION ON TRAIN SET ------
# RMSE 397813.8038017269
# R^2:  0.6219552116625728

# %% [markdown]
# ## EXERCICE - TRAIN A MODEL and upload your best solution to the Kaggle Challenge
#
# Tasks:
# + Choose the best features for the problem. Some features are numercial but others categorical, think how to codify all of them.
# + Choose the model. You have two choice: LinearRegression and KNeighborsRegressor
#     + You can chanege the paramenter n_neighbors from the KNeighborsRegressor
#
# LINEAR REGRESSOR:
# >from sklearn.linear_model import LinearRegression
#
# >model = LinearRegression()
#
# KNeighborsRegressor
# > from sklearn import neighbors
#
# > n_neighbors = 3 # you can modify this paramenter (ONLY THIS ONE!!!)
#
# > model = neighbors.KNeighborsRegressor(n_neighbors=n_neighbors)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
correlation = train_set.corr()
sns.heatmap(correlation, vmax=1, square=True)
plt.show()

# %% [markdown]
# Com es pot observar, les correlacions més interessants es troben Rooms-Bedroom, Price-YearBuilt, Rooms-Bathroom. Si filem més prim podem veure que Car, Distance, Landsize i BuildingArea també tenen rellevància.

# %%
cols = ['Landsize', 'BuildingArea', 'YearBuilt', 'Car', 'Distance', 'Propertycount', 'Rooms', 'Bedroom2', 'Bathroom']
for column in cols:
    train_set[column] = train_set[column].fillna(train_set[column].mean())
    test_set[column] = test_set[column].fillna(test_set[column].mean())

# %%
#OUTLIERS

cols = ['Landsize', 'BuildingArea', 'YearBuilt', 'Car', 'Distance', 'Propertycount', 'Rooms', 'Bedroom2', 'Bathroom']
for column in cols:
    quan_ba_low_tr = train_set[column].quantile(0.01)
    quan_ba_high_tr = train_set[column].quantile(0.99)
    quan_ba_low = test_set[column].quantile(0.01)
    quan_ba_high = test_set[column].quantile(0.99)

    train_set.loc[train_set[column] < quan_ba_low_tr, column] = train_set[column].mean()
    train_set.loc[train_set[column] > quan_ba_high_tr, column] = train_set[column].mean()

    test_set.loc[test_set[column] < quan_ba_low, column] = test_set[column].mean()
    test_set.loc[test_set[column] > quan_ba_high, column] = test_set[column].mean()

train_set
# Out:
#                   Suburb           Address  Rooms Type      Price Method  \
# index
# 0             Aberfeldie    241 Buckley St    4.0    h  1380000.0     VB
# 1              Northcote     67 Charles St    2.0    h  1100000.0     SP
# 2           Balwyn North        42 Maud St    3.0    h  1480000.0     PI
# 3              Brunswick       13 Percy St    3.0    h  1055000.0      S
# 4      Templestowe Lower  253 Thompsons Rd    4.0    h  1000000.0     VB
# ...                  ...               ...    ...  ...        ...    ...
# 5427           Reservoir     30 Kinsale St    3.0    h   851500.0      S
# 5428       Fitzroy North   134 Clauscen St    2.0    h  1400000.0      S
# 5429            Richmond   23a Dickmann St    3.0    t   975000.0     PI
# 5430      Bentleigh East    21 Highview Rd    2.0    h   722000.0      S
# 5431      West Footscray    31 Napoleon St    3.0    h   860000.0      S
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# index
# 0             Nelson  12/08/2017       7.5    3040.0       4.0       2.0  2.0
# 1             Jellis  20/05/2017       5.5    3070.0       2.0       1.0  1.0
# 2             Jellis  15/10/2016       9.2    3104.0       3.0       1.0  4.0
# 3             Nelson   7/05/2016       5.2    3056.0       3.0       1.0  1.0
# 4      hockingstuart  13/08/2016      13.8    3107.0       4.0       3.0  2.0
# ...              ...         ...       ...       ...       ...       ...  ...
# 5427          Nelson  22/08/2016      11.2    3073.0       3.0       1.0  1.0
# 5428          Nelson  26/08/2017       3.6    3068.0       2.0       1.0  1.0
# 5429          Jellis  22/08/2016       2.6    3121.0       3.0       1.0  1.0
# 5430          Buxton  16/04/2016      13.9    3165.0       2.0       2.0  1.0
# 5431          Biggin  26/07/2016       8.2    3012.0       3.0       1.0  2.0
#
#        Landsize  BuildingArea    YearBuilt    CouncilArea  Lattitude  \
# index
# 0         766.0     163.46243  1965.219564  Moonee Valley  -37.75595
# 1         189.0     163.46243  1965.219564        Darebin  -37.77670
# 2         605.0     116.00000  1950.000000     Boroondara  -37.79510
# 3         324.0     163.46243  1930.000000       Moreland  -37.76530
# 4         728.0     164.00000  1970.000000     Manningham  -37.76800
# ...         ...           ...          ...            ...        ...
# 5427        0.0     163.46243  1930.000000        Darebin  -37.72170
# 5428      164.0      93.00000  1890.000000            NaN  -37.77796
# 5429      383.0     163.46243  1993.000000          Yarra  -37.82480
# 5430      201.0      79.00000  2005.000000      Glen Eira  -37.92930
# 5431      501.0     147.00000  1960.000000    Maribyrnong  -37.79120
#
#        Longtitude             Regionname  Propertycount
# index
# 0       144.90551   Western Metropolitan         1543.0
# 1       144.99240  Northern Metropolitan        11364.0
# 2       145.06960  Southern Metropolitan         7809.0
# 3       144.95860  Northern Metropolitan        11918.0
# 4       145.10270   Eastern Metropolitan         5420.0
# ...           ...                    ...            ...
# 5427    144.99540  Northern Metropolitan        21650.0
# 5428    144.98374  Northern Metropolitan         6244.0
# 5429    144.99760  Northern Metropolitan        14949.0
# 5430    145.06570  Southern Metropolitan        10969.0
# 5431    144.86800   Western Metropolitan         5058.0
#
# [5432 rows x 21 columns]

# %%
#POTENCIAR
train_set['Corr_prod'] = train_set['Rooms'] * train_set['Bedroom2'] * train_set['Bathroom']
test_set['Corr_prod'] = test_set['Rooms'] * test_set['Bedroom2'] * test_set['Bathroom']

train_set['Corr_sum'] = train_set['Rooms'] + train_set['Bedroom2'] + train_set['Bathroom']
test_set['Corr_sum'] = test_set['Rooms'] + test_set['Bedroom2'] + test_set['Bathroom']

train_set['Rooms_pw'] = train_set['Rooms'] ** 2
test_set['Rooms_pw'] = test_set['Rooms'] ** 2

train_set['Rooms_sqr'] = train_set['Rooms'] ** (1/2)
test_set['Rooms_sqr'] = test_set['Rooms'] ** (1/2)

cols = ['Landsize', 'BuildingArea', 'YearBuilt', 'Car', 'Distance', 'Propertycount', 'Corr_sum', 'Rooms']

#normalitzar
for col in cols:
    train_set[col] = (train_set[col] - train_set[col].min())/(train_set[col].max() - train_set[col].min())
    test_set[col] = (test_set[col] - test_set[col].min())/(test_set[col].max() - test_set[col].min())
train_set
# Out:
#                   Suburb           Address  Rooms Type      Price Method  \
# index
# 0             Aberfeldie    241 Buckley St   0.75    h  1380000.0     VB
# 1              Northcote     67 Charles St   0.25    h  1100000.0     SP
# 2           Balwyn North        42 Maud St   0.50    h  1480000.0     PI
# 3              Brunswick       13 Percy St   0.50    h  1055000.0      S
# 4      Templestowe Lower  253 Thompsons Rd   0.75    h  1000000.0     VB
# ...                  ...               ...    ...  ...        ...    ...
# 5427           Reservoir     30 Kinsale St   0.50    h   851500.0      S
# 5428       Fitzroy North   134 Clauscen St   0.25    h  1400000.0      S
# 5429            Richmond   23a Dickmann St   0.50    t   975000.0     PI
# 5430      Bentleigh East    21 Highview Rd   0.25    h   722000.0      S
# 5431      West Footscray    31 Napoleon St   0.50    h   860000.0      S
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# index
# 0             Nelson  12/08/2017  0.181538    3040.0       4.0       2.0  0.4
# 1             Jellis  20/05/2017  0.120000    3070.0       2.0       1.0  0.2
# 2             Jellis  15/10/2016  0.233846    3104.0       3.0       1.0  0.8
# 3             Nelson   7/05/2016  0.110769    3056.0       3.0       1.0  0.2
# 4      hockingstuart  13/08/2016  0.375385    3107.0       4.0       3.0  0.4
# ...              ...         ...       ...       ...       ...       ...  ...
# 5427          Nelson  22/08/2016  0.295385    3073.0       3.0       1.0  0.2
# 5428          Nelson  26/08/2017  0.061538    3068.0       2.0       1.0  0.2
# 5429          Jellis  22/08/2016  0.030769    3121.0       3.0       1.0  0.2
# 5430          Buxton  16/04/2016  0.378462    3165.0       2.0       2.0  0.2
# 5431          Biggin  26/07/2016  0.203077    3012.0       3.0       1.0  0.4
#
#        Landsize  BuildingArea  YearBuilt    CouncilArea  Lattitude  \
# index
# 0      0.282032      0.374526   0.601757  Moonee Valley  -37.75595
# 1      0.069588      0.374526   0.601757        Darebin  -37.77670
# 2      0.222754      0.236152   0.480000     Boroondara  -37.79510
# 3      0.119293      0.374526   0.320000       Moreland  -37.76530
# 4      0.268041      0.376093   0.640000     Manningham  -37.76800
# ...         ...           ...        ...            ...        ...
# 5427   0.000000      0.374526   0.320000        Darebin  -37.72170
# 5428   0.060383      0.169096   0.000000            NaN  -37.77796
# 5429   0.141016      0.374526   0.824000          Yarra  -37.82480
# 5430   0.074006      0.128280   0.920000      Glen Eira  -37.92930
# 5431   0.184462      0.326531   0.560000    Maribyrnong  -37.79120
#
#        Longtitude             Regionname  Propertycount  Corr_prod  Corr_sum  \
# index
# 0       144.90551   Western Metropolitan       0.031361       32.0  0.636364
# 1       144.99240  Northern Metropolitan       0.504480        4.0  0.181818
# 2       145.06960  Southern Metropolitan       0.333221        9.0  0.363636
# 3       144.95860  Northern Metropolitan       0.531169        9.0  0.363636
# 4       145.10270   Eastern Metropolitan       0.218133       48.0  0.727273
# ...           ...                    ...            ...        ...       ...
# 5427    144.99540  Northern Metropolitan       1.000000        9.0  0.363636
# 5428    144.98374  Northern Metropolitan       0.257828        4.0  0.181818
# 5429    144.99760  Northern Metropolitan       0.677185        9.0  0.363636
# 5430    145.06570  Southern Metropolitan       0.485451        8.0  0.272727
# 5431    144.86800   Western Metropolitan       0.200694        9.0  0.363636
#
#        Rooms_pw  Rooms_sqr
# index
# 0          16.0   2.000000
# 1           4.0   1.414214
# 2           9.0   1.732051
# 3           9.0   1.732051
# 4          16.0   2.000000
# ...         ...        ...
# 5427        9.0   1.732051
# 5428        4.0   1.414214
# 5429        9.0   1.732051
# 5430        4.0   1.414214
# 5431        9.0   1.732051
#
# [5432 rows x 25 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 5))
correlation = train_set.corr()
sns.heatmap(correlation, vmax=.8, square=True)
plt.show()
correlation
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496103  0.294429  0.066658  0.960780  0.569787
# Price          0.496103  1.000000 -0.163010  0.093127  0.477782  0.447607
# Distance       0.294429 -0.163010  1.000000  0.319901  0.303814  0.129449
# Postcode       0.066658  0.093127  0.319901  1.000000  0.070944  0.115042
# Bedroom2       0.960780  0.477782  0.303814  0.070944  1.000000  0.565827
# Bathroom       0.569787  0.447607  0.129449  0.115042  0.565827  1.000000
# Car            0.408695  0.235760  0.283346  0.057088  0.406523  0.308729
# Landsize       0.344637  0.248354  0.294349  0.079120  0.341163  0.157535
# BuildingArea   0.508247  0.418611  0.154339  0.073232  0.506007  0.452902
# YearBuilt     -0.047035 -0.256488  0.204602  0.052844 -0.031994  0.139549
# Lattitude      0.001679 -0.206769 -0.044274 -0.407233  0.005609 -0.072628
# Longtitude     0.079221  0.199303  0.186849  0.435858  0.080355  0.110368
# Propertycount -0.080133 -0.041669 -0.078057  0.065947 -0.079120 -0.062997
# Corr_prod      0.827546  0.509796  0.201479  0.102159  0.827930  0.834780
# Corr_sum       0.962131  0.525859  0.280573  0.089389  0.960850  0.752526
# Rooms_pw       0.979016  0.493539  0.266006  0.073977  0.936802  0.583954
# Rooms_sqr      0.992852  0.488807  0.303120  0.060702  0.956183  0.549976
#
#                     Car  Landsize  BuildingArea  YearBuilt  Lattitude  \
# Rooms          0.408695  0.344637      0.508247  -0.047035   0.001679
# Price          0.235760  0.248354      0.418611  -0.256488  -0.206769
# Distance       0.283346  0.294349      0.154339   0.204602  -0.044274
# Postcode       0.057088  0.079120      0.073232   0.052844  -0.407233
# Bedroom2       0.406523  0.341163      0.506007  -0.031994   0.005609
# Bathroom       0.308729  0.157535      0.452902   0.139549  -0.072628
# Car            1.000000  0.296912      0.279250   0.102202  -0.021929
# Landsize       0.296912  1.000000      0.246709  -0.059602   0.013110
# BuildingArea   0.279250  0.246709      1.000000   0.042406  -0.040025
# YearBuilt      0.102202 -0.059602      0.042406   1.000000   0.033600
# Lattitude     -0.021929  0.013110     -0.040025   0.033600   1.000000
# Longtitude     0.066834  0.128369      0.094934  -0.011532  -0.364389
# Propertycount -0.032909 -0.064853     -0.053738   0.011623   0.052311
# Corr_prod      0.363366  0.277721      0.517558   0.041012  -0.042052
# Corr_sum       0.420936  0.324325      0.543764   0.008577  -0.018221
# Rooms_pw       0.391091  0.340509      0.507387  -0.039674  -0.009330
# Rooms_sqr      0.409087  0.338547      0.497921  -0.050847   0.008012
#
#                Longtitude  Propertycount  Corr_prod  Corr_sum  Rooms_pw  \
# Rooms            0.079221      -0.080133   0.827546  0.962131  0.979016
# Price            0.199303      -0.041669   0.509796  0.525859  0.493539
# Distance         0.186849      -0.078057   0.201479  0.280573  0.266006
# Postcode         0.435858       0.065947   0.102159  0.089389  0.073977
# Bedroom2         0.080355      -0.079120   0.827930  0.960850  0.936802
# Bathroom         0.110368      -0.062997   0.834780  0.752526  0.583954
# Car              0.066834      -0.032909   0.363366  0.420936  0.391091
# Landsize         0.128369      -0.064853   0.277721  0.324325  0.340509
# BuildingArea     0.094934      -0.053738   0.517558  0.543764  0.507387
# YearBuilt       -0.011532       0.011623   0.041012  0.008577 -0.039674
# Lattitude       -0.364389       0.052311  -0.042052 -0.018221 -0.009330
# Longtitude       1.000000       0.053295   0.115850  0.096952  0.087956
# Propertycount    0.053295       1.000000  -0.067723 -0.083014 -0.070564
# Corr_prod        0.115850      -0.067723   1.000000  0.915386  0.876731
# Corr_sum         0.096952      -0.083014   0.915386  1.000000  0.948014
# Rooms_pw         0.087956      -0.070564   0.876731  0.948014  1.000000
# Rooms_sqr        0.073190      -0.083760   0.785008  0.951584  0.948362
#
#                Rooms_sqr
# Rooms           0.992852
# Price           0.488807
# Distance        0.303120
# Postcode        0.060702
# Bedroom2        0.956183
# Bathroom        0.549976
# Car             0.409087
# Landsize        0.338547
# BuildingArea    0.497921
# YearBuilt      -0.050847
# Lattitude       0.008012
# Longtitude      0.073190
# Propertycount  -0.083760
# Corr_prod       0.785008
# Corr_sum        0.951584
# Rooms_pw        0.948362
# Rooms_sqr       1.000000

# %%
## the features

features = ['Landsize', 'BuildingArea', 'YearBuilt', 'Car', 'Distance', 'Propertycount', 'Corr_sum', 'Rooms']
## DEFINE YOUR FEATURES
X = train_set[features].fillna(0)
y = train_set[['Price']]
## the model
# KNeighborsRegressor

from sklearn import neighbors

n_neighbors = 3# you can modify this paramenter (ONLY THIS ONE!!!)

model = neighbors.KNeighborsRegressor(n_neighbors=n_neighbors)
## fit the model
model.fit(X, y)

## predict training set
y_pred = model.predict(X)

## Evaluate the model and plot it
from sklearn.metrics import mean_squared_error, r2_score
print("----- EVALUATION ON TRAIN SET ------")
print("RMSE",np.sqrt(mean_squared_error(y, y_pred)))
print("R^2: ",r2_score(y, y_pred))


plt.scatter(y, y_pred)
plt.xlabel('Price')
plt.ylabel('Predicted price');
plt.show()

## predict the test set and generate the submission file
X_test = test_set[features].fillna(0)
y_pred = model.predict(X_test)

df_output = pd.DataFrame(y_pred)
df_output = df_output.reset_index()
df_output.columns = ['index','Price']

df_output.to_csv('output/session1/problem_submission.csv',index=False)
# Out:
# ----- EVALUATION ON TRAIN SET ------
# RMSE 324304.3830657947
# R^2:  0.7487597629026469

# %% [markdown]
# Explain the choosed model and why you think that is is the best
